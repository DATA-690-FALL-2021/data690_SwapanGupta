# %% [markdown]
# <a href="https://colab.research.google.com/github/SwapanGupt/data690_SwapanGupta/blob/main/Individual_project_PartB/Individual_Project_PartB_Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("/content/wdi_data (5).csv")
df.head()
# Out:
#    Unnamed: 0  Year  ...         Income Group Lending Type
# 0           0  2015  ...           Low income          IDA
# 1           1  2016  ...           Low income          IDA
# 2           2  2017  ...           Low income          IDA
# 3           3  2018  ...           Low income          IDA
# 4           4  2015  ...  Upper middle income         IBRD
#
# [5 rows x 9 columns]

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)
df
# Out:
#       Year    value  ...         Income Group Lending Type
# 0     2015   22.200  ...           Low income          IDA
# 1     2016   81.640  ...           Low income          IDA
# 2     2017   91.890  ...           Low income          IDA
# 3     2018  111.720  ...           Low income          IDA
# 4     2015  177.800  ...  Upper middle income         IBRD
# ...    ...      ...  ...                  ...          ...
# 6236  2015   59.534  ...  Lower middle income        Blend
# 6237  2016   60.294  ...  Lower middle income        Blend
# 6238  2017   60.812  ...  Lower middle income        Blend
# 6239  2018   61.195  ...  Lower middle income        Blend
# 6240  2019   61.490  ...  Lower middle income        Blend
#
# [6241 rows x 8 columns]

# %%
df_ind = df[df["Country Name"]=='India']
df_ind.head()
# Out:
#       Year          value  ...         Income Group Lending Type
# 308   2015  101813.080000  ...  Lower middle income         IBRD
# 309   2016  112167.340000  ...  Lower middle income         IBRD
# 310   2017  121631.310000  ...  Lower middle income         IBRD
# 311   2018  135787.790000  ...  Lower middle income         IBRD
# 1091  2015       8.039628  ...  Lower middle income         IBRD
#
# [5 rows x 8 columns]

# %%
df_usa = df[df["Country Name"]=='United States']
df_usa.head()
# Out:
#       Year          value  ... Income Group    Lending Type
# 748   2015  429988.890000  ...  High income  Not classified
# 749   2016  427264.630000  ...  High income  Not classified
# 750   2017  432216.490000  ...  High income  Not classified
# 751   2018  422807.710000  ...  High income  Not classified
# 1498  2015      21.759867  ...  High income  Not classified
#
# [5 rows x 8 columns]

# %%
df_chi = df[df["Country Name"]=='China']
df_chi.head()
# Out:
#      Year          value  ...         Income Group Lending Type
# 140  2015  407974.610000  ...  Upper middle income         IBRD
# 141  2016  438348.740000  ...  Upper middle income         IBRD
# 142  2017  473438.510000  ...  Upper middle income         IBRD
# 143  2018  528263.250000  ...  Upper middle income         IBRD
# 926  2015      30.423108  ...  Upper middle income         IBRD
#
# [5 rows x 8 columns]

# %%
df_uk = df[df["Country Name"]=='United Kingdom']
df_uk.head()
# Out:
#       Year         value  ... Income Group    Lending Type
# 744   2015  99616.020000  ...  High income  Not classified
# 745   2016  99366.170000  ...  High income  Not classified
# 746   2017  99128.720000  ...  High income  Not classified
# 747   2018  97680.900000  ...  High income  Not classified
# 1492  2015     22.634223  ...  High income  Not classified
#
# [5 rows x 8 columns]

# %%
df_aus = df[df["Country Name"]=='Australia']
df_aus.head()
# Out:
#      Year         value  ... Income Group    Lending Type
# 32   2015  52945.010000  ...  High income  Not classified
# 33   2016  53781.620000  ...  High income  Not classified
# 34   2017  53428.790000  ...  High income  Not classified
# 35   2018  53610.220000  ...  High income  Not classified
# 821  2015     19.817927  ...  High income  Not classified
#
# [5 rows x 8 columns]

# %%
df_uae = df[df["Country Name"]=='United Arab Emirates']
df_uae.head()
# Out:
#       Year        value  ... Income Group    Lending Type
# 740   2015  2294.580000  ...  High income  Not classified
# 741   2016  2484.160000  ...  High income  Not classified
# 742   2017  2899.670000  ...  High income  Not classified
# 743   2018  3144.890000  ...  High income  Not classified
# 1487  2015     5.311027  ...  High income  Not classified
#
# [5 rows x 8 columns]

# %%
frames=[df_aus,df_chi,df_ind,df_uae,df_uk,df_usa]
result= pd.concat(frames)
result
# Out:
#       Year         value  ... Income Group    Lending Type
# 32    2015  52945.010000  ...  High income  Not classified
# 33    2016  53781.620000  ...  High income  Not classified
# 34    2017  53428.790000  ...  High income  Not classified
# 35    2018  53610.220000  ...  High income  Not classified
# 821   2015     19.817927  ...  High income  Not classified
# ...    ...           ...  ...          ...             ...
# 6186  2015     78.690244  ...  High income  Not classified
# 6187  2016     78.539024  ...  High income  Not classified
# 6188  2017     78.539024  ...  High income  Not classified
# 6189  2018     78.639024  ...  High income  Not classified
# 6190  2019     78.787805  ...  High income  Not classified
#
# [208 rows x 8 columns]

# %%
df_2015 = result.query("Year == 2015")
df_2015.sample(10)
# Out:
#       Year         value  ...         Income Group    Lending Type
# 2926  2015  1.371220e+09  ...  Upper middle income            IBRD
# 6186  2015  7.869024e+01  ...          High income  Not classified
# 2621  2015  6.490188e+04  ...          High income  Not classified
# 748   2015  4.299889e+05  ...          High income  Not classified
# 6181  2015  8.095610e+01  ...          High income  Not classified
# 5428  2015  7.592800e+01  ...  Upper middle income            IBRD
# 4841  2015  8.800000e+00  ...          High income  Not classified
# 3208  2015  1.310152e+09  ...  Lower middle income            IBRD
# 5654  2015  6.860700e+01  ...  Lower middle income            IBRD
# 4846  2015  1.440000e+01  ...          High income  Not classified
#
# [10 rows x 8 columns]

# %%
df_2015 = df_2015.query("indicator in ['NY.GDP.PCAP.PP.CD','SP.POP.TOTL','GB.XPD.RSDV.GD.ZS','IP.JRN.ARTC.SC','TX.VAL.TECH.MF.ZS']"	)
df_2015.head()
# Out:
#       Year         value  ... Income Group    Lending Type
# 32    2015  5.294501e+04  ...  High income  Not classified
# 821   2015  1.981793e+01  ...  High income  Not classified
# 1580  2015  4.628833e+04  ...  High income  Not classified
# 2740  2015  2.381600e+07  ...  High income  Not classified
# 4900  2015  1.919430e+00  ...  High income  Not classified
#
# [5 rows x 8 columns]

# %%
df_pivot = df_2015.pivot(index =['Country Code','Country Name','Region','Income Group','Lending Type'], columns='indicator', values='value').reset_index()
df_pivot.head()
# Out:
# indicator Country Code          Country Name  ...   SP.POP.TOTL TX.VAL.TECH.MF.ZS
# 0                  ARE  United Arab Emirates  ...  9.262896e+06          5.311027
# 1                  AUS             Australia  ...  2.381600e+07         19.817927
# 2                  CHN                 China  ...  1.371220e+09         30.423108
# 3                  GBR        United Kingdom  ...  6.511622e+07         22.634223
# 4                  IND                 India  ...  1.310152e+09          8.039628
#
# [5 rows x 10 columns]

# %%
fig = px.pie(
    df_pivot,
    values='NY.GDP.PCAP.PP.CD', 
    names='Country Name',
    title='TOP 6 Countries by 2015 GDP per capita,PPP(Current International $)',
    hover_name='Country Code',
)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5ec5cf27-dc52-4701-88d6-92827b19a3c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5ec5cf27-dc52-4701-88d6-92827b19a3c9")) {
#                     Plotly.newPlot(
#                         '5ec5cf27-dc52-4701-88d6-92827b19a3c9',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=%{label}<br>NY.GDP.PCAP.PP.CD=%{value}", "hovertext": ["ARE", "AUS", "CHN", "GBR", "IND", "USA"], "labels": ["United Arab Emirates", "Australia", "China", "United Kingdom", "India", "United States"], "legendgroup": "", "name": "", "showlegend": true, "textinfo": "percent+label", "textposition": "inside", "type": "pie", "values": [64901.880051235195, 46288.334478641395, 12978.7689105655, 42567.5917974837, 5464.859178008, 56863.3714957652]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
fig = px.bar(
    df_pivot,
    x="Country Name",
    y="SP.POP.TOTL",
    title="TOP 6 Countries By 2015 Population,Total",
    color='Country Name',
    labels={"SP.POP.TOTL":"2015 Population,Total"}
).update_xaxes(categoryorder="total descending")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="94a05d3e-833a-46fd-9e28-be191ababb85" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("94a05d3e-833a-46fd-9e28-be191ababb85")) {
#                     Plotly.newPlot(
#                         '94a05d3e-833a-46fd-9e28-be191ababb85',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2015 Population,Total=%{y}", "legendgroup": "Country Name=United Arab Emirates", "marker": {"color": "#636efa"}, "name": "Country Name=United Arab Emirates", "offsetgroup": "Country Name=United Arab Emirates", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Arab Emirates"], "xaxis": "x", "y": [9262896.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2015 Population,Total=%{y}", "legendgroup": "Country Name=Australia", "marker": {"color": "#EF553B"}, "name": "Country Name=Australia", "offsetgroup": "Country Name=Australia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Australia"], "xaxis": "x", "y": [23815995.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2015 Population,Total=%{y}", "legendgroup": "Country Name=China", "marker": {"color": "#00cc96"}, "name": "Country Name=China", "offsetgroup": "Country Name=China", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["China"], "xaxis": "x", "y": [1371220000.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2015 Population,Total=%{y}", "legendgroup": "Country Name=United Kingdom", "marker": {"color": "#ab63fa"}, "name": "Country Name=United Kingdom", "offsetgroup": "Country Name=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [65116219.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2015 Population,Total=%{y}", "legendgroup": "Country Name=India", "marker": {"color": "#FFA15A"}, "name": "Country Name=India", "offsetgroup": "Country Name=India", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["India"], "xaxis": "x", "y": [1310152392.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2015 Population,Total=%{y}", "legendgroup": "Country Name=United States", "marker": {"color": "#19d3f3"}, "name": "Country Name=United States", "offsetgroup": "Country Name=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [320738994.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
fig = px.bar(
    df_pivot,
    x="Country Name",
    y="GB.XPD.RSDV.GD.ZS",
    title="TOP 6 Countries by 2015 Research and Development Expenditure(% of GDP)",
    color='Country Name',
    labels={"GB.XPD.RSDV.GD.ZS":"2015 Research and Development Expenditure(% of GDP)"}
    
).update_xaxes(categoryorder="total descending")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ac06b33f-3b09-4c83-90e5-ed9b975820b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ac06b33f-3b09-4c83-90e5-ed9b975820b5")) {
#                     Plotly.newPlot(
#                         'ac06b33f-3b09-4c83-90e5-ed9b975820b5',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2015 Research and Development Expenditure(% of GDP)=%{y}", "legendgroup": "Country Name=United Arab Emirates", "marker": {"color": "#636efa"}, "name": "Country Name=United Arab Emirates", "offsetgroup": "Country Name=United Arab Emirates", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Arab Emirates"], "xaxis": "x", "y": [0.8950400000000001], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2015 Research and Development Expenditure(% of GDP)=%{y}", "legendgroup": "Country Name=Australia", "marker": {"color": "#EF553B"}, "name": "Country Name=Australia", "offsetgroup": "Country Name=Australia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Australia"], "xaxis": "x", "y": [1.91943], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2015 Research and Development Expenditure(% of GDP)=%{y}", "legendgroup": "Country Name=China", "marker": {"color": "#00cc96"}, "name": "Country Name=China", "offsetgroup": "Country Name=China", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["China"], "xaxis": "x", "y": [2.0656], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2015 Research and Development Expenditure(% of GDP)=%{y}", "legendgroup": "Country Name=United Kingdom", "marker": {"color": "#ab63fa"}, "name": "Country Name=United Kingdom", "offsetgroup": "Country Name=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [1.66818], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2015 Research and Development Expenditure(% of GDP)=%{y}", "legendgroup": "Country Name=India", "marker": {"color": "#FFA15A"}, "name": "Country Name=India", "offsetgroup": "Country Name=India", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["India"], "xaxis": "x", "y": [0.6931], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2015 Research and Development Expenditure(% of GDP)=%{y}", "legendgroup": "Country Name=United States", "marker": {"color": "#19d3f3"}, "name": "Country Name=United States", "offsetgroup": "Country Name=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [2.71742], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
df_new = result.query("indicator in ['NY.GDP.PCAP.PP.CD','SP.POP.TOTL','GB.XPD.RSDV.GD.ZS','IP.JRN.ARTC.SC','TX.VAL.TECH.MF.ZS']"	)
df_new
# Out:
#       Year         value  ... Income Group    Lending Type
# 32    2015  5.294501e+04  ...  High income  Not classified
# 33    2016  5.378162e+04  ...  High income  Not classified
# 34    2017  5.342879e+04  ...  High income  Not classified
# 35    2018  5.361022e+04  ...  High income  Not classified
# 821   2015  1.981793e+01  ...  High income  Not classified
# ...    ...           ...  ...          ...             ...
# 3915  2020  3.294841e+08  ...  High income  Not classified
# 5230  2015  2.717420e+00  ...  High income  Not classified
# 5231  2016  2.761450e+00  ...  High income  Not classified
# 5232  2017  2.817410e+00  ...  High income  Not classified
# 5233  2018  2.837660e+00  ...  High income  Not classified
#
# [148 rows x 8 columns]

# %%
df_pivot2 = df_new.pivot(index =['Year','Country Code','Country Name','Region','Income Group','Lending Type'], columns='indicator', values='value').reset_index()
df_pivot2.sample(5)
# Out:
# indicator  Year Country Code  ...   SP.POP.TOTL TX.VAL.TECH.MF.ZS
# 31         2020          AUS  ...  2.568704e+07               NaN
# 25         2019          AUS  ...  2.536574e+07         21.524704
# 21         2018          GBR  ...  6.646034e+07         22.717194
# 23         2018          USA  ...  3.268382e+08         18.741741
# 32         2020          CHN  ...  1.402112e+09               NaN
#
# [5 rows x 11 columns]

# %%
fig = px.line(df_pivot2,
    x="Year",
    y="TX.VAL.TECH.MF.ZS",
    title="TOP 6 Countries by High-technology exports (% of manufactured exports)",
    color='Country Name',
    labels={"Year":"Year","TX.VAL.TECH.MF.ZS":"High-technology exports (% of manufactured exports)"},
    hover_name='Country Name',
    
)
fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0cf94a05-5f5f-4692-9d3d-7d89dda752c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0cf94a05-5f5f-4692-9d3d-7d89dda752c7")) {
#                     Plotly.newPlot(
#                         '0cf94a05-5f5f-4692-9d3d-7d89dda752c7',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=United Arab Emirates<br>Year=%{x}<br>High-technology exports (% of manufactured exports)=%{y}", "hovertext": ["United Arab Emirates", "United Arab Emirates", "United Arab Emirates", "United Arab Emirates", "United Arab Emirates", "United Arab Emirates"], "legendgroup": "Country Name=United Arab Emirates", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Country Name=United Arab Emirates", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [5.3110274225, 2.6179152963, 2.7214237579, 3.0524010882, 2.8952658633999997, null], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Australia<br>Year=%{x}<br>High-technology exports (% of manufactured exports)=%{y}", "hovertext": ["Australia", "Australia", "Australia", "Australia", "Australia", "Australia"], "legendgroup": "Country Name=Australia", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Country Name=Australia", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [19.8179269594, 20.7310511455, 17.9618545366, 18.3247962772, 21.524703604299997, null], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=China<br>Year=%{x}<br>High-technology exports (% of manufactured exports)=%{y}", "hovertext": ["China", "China", "China", "China", "China", "China"], "legendgroup": "Country Name=China", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Country Name=China", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [30.4231080446, 30.244219815799998, 30.9086941356, 31.4695809261, 30.7850120883, null], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=United Kingdom<br>Year=%{x}<br>High-technology exports (% of manufactured exports)=%{y}", "hovertext": ["United Kingdom", "United Kingdom", "United Kingdom", "United Kingdom", "United Kingdom", "United Kingdom"], "legendgroup": "Country Name=United Kingdom", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "Country Name=United Kingdom", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [22.634222874899997, 23.9271805206, 23.093210623, 22.7171943235, 23.4681303188, 23.098625111999997], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=India<br>Year=%{x}<br>High-technology exports (% of manufactured exports)=%{y}", "hovertext": ["India", "India", "India", "India", "India", "India"], "legendgroup": "Country Name=India", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "Country Name=India", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [8.039628032000001, 7.6815236929, 7.389559618400001, 9.081063796, 10.2988643763, null], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=United States<br>Year=%{x}<br>High-technology exports (% of manufactured exports)=%{y}", "hovertext": ["United States", "United States", "United States", "United States", "United States", "United States"], "legendgroup": "Country Name=United States", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "Country Name=United States", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [21.7598671248, 22.723747137399997, 19.519901695999998, 18.7417405398, 18.9335479864, 19.7523940309], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d"

# %%
fig = px.scatter(
    df_pivot.dropna(),
    x="NY.GDP.PCAP.PP.CD",
    y="IP.JRN.ARTC.SC",
    title="TOP 6 Countries by 2015 Scientific and Technical Journal Articles",
    labels={"NY.GDP.PCAP.PP.CD":"2015 GDP per Capita,PPP(current international $)","IP.JRN.ARTC.SC":"2015 Scientific and Technical Journal Articles"},
    color='Country Name',
    hover_name='Country Name',
    size="SP.POP.TOTL",
    size_max=75
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7eff7127-ffdb-4779-9112-657b71fdfb00" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7eff7127-ffdb-4779-9112-657b71fdfb00")) {
#                     Plotly.newPlot(
#                         '7eff7127-ffdb-4779-9112-657b71fdfb00',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=United Arab Emirates<br>2015 GDP per Capita,PPP(current international $)=%{x}<br>2015 Scientific and Technical Journal Articles=%{y}<br>SP.POP.TOTL=%{marker.size}", "hovertext": ["United Arab Emirates"], "legendgroup": "Country Name=United Arab Emirates", "marker": {"color": "#636efa", "size": [9262896.0], "sizemode": "area", "sizeref": 243772.44444444444, "symbol": "circle"}, "mode": "markers", "name": "Country Name=United Arab Emirates", "showlegend": true, "type": "scatter", "x": [64901.880051235195], "xaxis": "x", "y": [2294.58], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Australia<br>2015 GDP per Capita,PPP(current international $)=%{x}<br>2015 Scientific and Technical Journal Articles=%{y}<br>SP.POP.TOTL=%{marker.size}", "hovertext": ["Australia"], "legendgroup": "Country Name=Australia", "marker": {"color": "#EF553B", "size": [23815995.0], "sizemode": "area", "sizeref": 243772.44444444444, "symbol": "circle"}, "mode": "markers", "name": "Country Name=Australia", "showlegend": true, "type": "scatter", "x": [46288.334478641395], "xaxis": "x", "y": [52945.01], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=China<br>2015 GDP per Capita,PPP(current international $)=%{x}<br>2015 Scientific and Technical Journal Articles=%{y}<br>SP.POP.TOTL=%{marker.size}", "hovertext": ["China"], "legendgroup": "Country Name=China", "marker": {"color": "#00cc96", "size": [1371220000.0], "sizemode": "area", "sizeref": 243772.44444444444, "symbol": "circle"}, "mode": "markers", "name": "Country Name=China", "showlegend": true, "type": "scatter", "x": [12978.7689105655], "xaxis": "x", "y": [407974.61], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=United Kingdom<br>2015 GDP per Capita,PPP(current international $)=%{x}<br>2015 Scientific and Technical Journal Articles=%{y}<br>SP.POP.TOTL=%{marker.size}", "hovertext": ["United Kingdom"], "legendgroup": "Country Name=United Kingdom", "marker": {"color": "#ab63fa", "size": [65116219.0], "sizemode": "area", "sizeref": 243772.44444444444, "symbol": "circle"}, "mode": "markers", "name": "Country Name=United Kingdom", "showlegend": true, "type": "scatter", "x": [42567.5917974837], "xaxis": "x", "y": [99616.02], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=India<br>2015 GDP per Capita,PPP(current international $)=%{x}<br>2015 Scientific and Technical Journal Articles=%{y}<br>SP.POP.TOTL=%{marker.size}", "hovertext": ["India"], "legendgroup": "Country Name=India", "marker": {"color": "#FFA15A", "size": [1310152392.0], "sizemode": "area", "sizeref": 243772.44444444444, "symbol": "circle"}, "mode": "markers", "name": "Country Name=India", "showlegend": true, "type": "scatter", "x": [5464.859178008], "xaxis": "x", "y": [101813.08], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=United States<br>2015 GDP per Capita,PPP(current international $)=%{x}<br>2015 Scientific and Technical Journal Articles=%{y}<br>SP.POP.TOTL=%{marker.size}", "hovertext": ["United States"], "legendgroup": "Country Name=United States", "marker": {"color": "#19d3f3", "size": [320738994.0], "sizemode": "area", "sizeref": 243772.44444444444, "symbol": "circle"}, "mode": "markers", "name": "Country Name=United States", "showlegend": true, "type": "scatter", "x": [56863.3714957652], "xaxis": "x", "y": [429988.89], "yaxis": "y"}],
#                         {"legend": {"itemsizing": "constant", "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks
