# %% [markdown]
# <a href="https://colab.research.google.com/github/SwapanGupt/data690_SwapanGupta/blob/main/Assignment07/in_class_practice_Session7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In-Class Practice Session 7
# - Name: Swapan Gupta
# - Date: 10/14/2021

# %%
import pandas as pd

print("Pandas Version is:",pd.__version__)

import plotly
print("Plotly Version is:",plotly.__version__)

import plotly.graph_objects as go
import plotly.express as px
# Out:
# Pandas Version is: 1.1.5
# Plotly Version is: 4.4.1

# %%
df = pd.read_csv("/content/wdi_data.csv")
df.head(10)
# Out:
#    Unnamed: 0  Year  ...         Income Group Lending Type
# 0           0  2015  ...           Low income          IDA
# 1           1  2016  ...           Low income          IDA
# 2           2  2017  ...           Low income          IDA
# 3           3  2018  ...           Low income          IDA
# 4           4  2019  ...           Low income          IDA
# 5           5  2020  ...           Low income          IDA
# 6           6  2015  ...  Upper middle income         IBRD
# 7           7  2016  ...  Upper middle income         IBRD
# 8           8  2017  ...  Upper middle income         IBRD
# 9           9  2018  ...  Upper middle income         IBRD
#
# [10 rows x 9 columns]

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)
df
#df_new = df.drop(columns=["Unnamed: 0"])
#df_new.head()
# Out:
#       Year        value  ...         Income Group Lending Type
# 0     2015  2087.305323  ...           Low income          IDA
# 1     2016  1981.118069  ...           Low income          IDA
# 2     2017  2058.400221  ...           Low income          IDA
# 3     2018  2082.635648  ...           Low income          IDA
# 4     2019  2152.366489  ...           Low income          IDA
# ...    ...          ...  ...                  ...          ...
# 4349  2015    18.000000  ...  Lower middle income        Blend
# 4350  2016    16.800000  ...  Lower middle income        Blend
# 4351  2017    15.000000  ...  Lower middle income        Blend
# 4352  2018    14.000000  ...  Lower middle income        Blend
# 4353  2019    14.100000  ...  Lower middle income        Blend
#
# [4354 rows x 8 columns]

# %%
#df_ind = df_new.query
df_ind = df[df["Country Code"]=='IND']
df_ind
# Out:
#       Year         value  ...         Income Group Lending Type
# 462   2015  5.464859e+03  ...  Lower middle income         IBRD
# 463   2016  5.839865e+03  ...  Lower middle income         IBRD
# 464   2017  6.182922e+03  ...  Lower middle income         IBRD
# 465   2018  6.675361e+03  ...  Lower middle income         IBRD
# 466   2019  6.997864e+03  ...  Lower middle income         IBRD
# 467   2020  6.454347e+03  ...  Lower middle income         IBRD
# 1556  2015  6.860700e+01  ...  Lower middle income         IBRD
# 1557  2016  6.889700e+01  ...  Lower middle income         IBRD
# 1558  2017  6.916500e+01  ...  Lower middle income         IBRD
# 1559  2018  6.941600e+01  ...  Lower middle income         IBRD
# 1560  2019  6.965600e+01  ...  Lower middle income         IBRD
# 2671  2015  1.310152e+09  ...  Lower middle income         IBRD
# 2672  2016  1.324517e+09  ...  Lower middle income         IBRD
# 2673  2017  1.338677e+09  ...  Lower middle income         IBRD
# ...

# %%
df_ind_gdppcap=df_ind.query("indicator == 'NY.GDP.PCAP.PP.CD'")
df_ind_gdppcap
# Out:
#      Year        value  ...         Income Group Lending Type
# 462  2015  5464.859178  ...  Lower middle income         IBRD
# 463  2016  5839.864817  ...  Lower middle income         IBRD
# 464  2017  6182.922109  ...  Lower middle income         IBRD
# 465  2018  6675.361294  ...  Lower middle income         IBRD
# 466  2019  6997.863988  ...  Lower middle income         IBRD
# 467  2020  6454.347356  ...  Lower middle income         IBRD
#
# [6 rows x 8 columns]

# %%
fig = go.Figure()

trace_0 = go.Bar(
    
    x=df_ind_gdppcap["Year"],
    y=df_ind_gdppcap["value"]
)

fig.add_trace(trace_0)
fig.update_layout(
    title="India GDP per Capita Over Time",
    xaxis_title="Year",
    yaxis_title="GDP per Capita"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="edc26382-9708-46e4-b15c-a7199271c56e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("edc26382-9708-46e4-b15c-a7199271c56e")) {
#                     Plotly.newPlot(
#                         'edc26382-9708-46e4-b15c-a7199271c56e',
# ...

# %%
fig = go.Figure()

trace_0 = go.Line(
    
    x=df_ind_gdppcap["Year"],
    y=df_ind_gdppcap["value"]
)

fig.add_trace(trace_0)
fig.update_layout(
    title="India GDP per Capita Over Time",
    xaxis_title="Year",
    yaxis_title="GDP per Capita"
)

fig.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:385: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0a9ad088-2d69-46a1-a980-40d5dfb17269" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
# ...

# %%
fig = px.bar(
    data_frame= df_ind_gdppcap,
    title="India GDP per Capita Over Time",
    labels={"value":"GDP per Capita","Year":"YEAR"},
    x="Year",
    y="value"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7bb4822d-772b-4484-bdd1-c8ef6be5d232" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7bb4822d-772b-4484-bdd1-c8ef6be5d232")) {
#                     Plotly.newPlot(
#                         '7bb4822d-772b-4484-bdd1-c8ef6be5d232',
# ...
